# %%
# Import libraries
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import csv
import re
import pandas as pd 
import time

# Set the URL you want to webscrape from
url = 'https://www.screener.in/screens/1/The-Bull-Cartel/'
# Connect to the URL
response = requests.get(url)

# Parse HTML and save to BeautifulSoup object
'''soup = BeautifulSoup(response.text, "html.parser")
data  = soup.findAll("table", class_ = "data-table")
data2 = data.findAll("a", class_ = "")
print(data)
'''

soup = BeautifulSoup(response.text, "html.parser")

#print(soup.find('a', href = re.compile(r'[/]([a-z]|[A-Z])\w+')).attrs['href'])
#print(type(soup))
for dataV1 in soup.findAll('table', attrs={'class':'data-table'}):
    #print(dataV1.find('a'))
    for a in dataV1.find_all('a'):
        siteUrl = a.get('href')
        if "?" not in siteUrl: 
            finalSiteUrl = "https://www.screener.in" + siteUrl
            print(finalSiteUrl)
        else:
            print("siteUrl")
        #print(a.get('href')) #for getting link
        #print(a.text) #for getting text between the link
    #dataV2 = dataV1.findAll('a')
    #print(dataV2)
    #print(type(dataV2))
    #print(div.find('a')['href'])
    #print(div.find('a').contents[0])
    #print(div.find('img')['src'])
# Out:
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# https://www.screener.in/company/BOMDYEING/
# https://www.screener.in/company/521178/
# https://www.screener.in/company/REFEX/
# https://www.screener.in/company/IOLCP/
# https://www.screener.in/company/PGHH/
# https://www.screener.in/company/532485/
# https://www.screener.in/company/508486/
# https://www.screener.in/company/DOLAT/
# https://www.screener.in/company/PARACABLES/
# https://www.screener.in/company/CAPLIPOINT/consolidated/
# https://www.screener.in/company/505358/
# https://www.screener.in/company/VSTIND/
# https://www.screener.in/company/POKARNA/consolidated/
# https://www.screener.in/company/GUFICBIO/
# https://www.screener.in/company/524790/
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# siteUrl
# https://www.screener.in/company/SATIA/
# https://www.screener.in/company/514183/
# ...
