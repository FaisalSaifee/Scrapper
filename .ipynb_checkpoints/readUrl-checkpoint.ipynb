# %%
# Import libraries
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import csv
import re
import pandas as pd 
import time

# Set the URL you want to webscrape from
url = 'https://www.screener.in/screens/1/The-Bull-Cartel/'
# Connect to the URL
response = requests.get(url)

# Parse HTML and save to BeautifulSoup object
'''soup = BeautifulSoup(response.text, "html.parser")
data  = soup.findAll("table", class_ = "data-table")
data2 = data.findAll("a", class_ = "")
print(data)
'''

soup = BeautifulSoup(response.text, "html.parser")

#print(soup.find('a', href = re.compile(r'[/]([a-z]|[A-Z])\w+')).attrs['href'])
#print(type(soup))
for dataV1 in soup.findAll('table', attrs={'class':'data-table'}):
    #print(dataV1.find('a'))
    for a in dataV1.find_all('a'):
        print(a.get('href')) #for getting link
        #print(a.text) #for getting text between the link
    #dataV2 = dataV1.findAll('a')
    #print(dataV2)
    #print(type(dataV2))
    #print(div.find('a')['href'])
    #print(div.find('a').contents[0])
    #print(div.find('img')['src'])
# Out:
# ?order=asc
# ?sort=name&order=desc
# ?sort=Current+Price&order=desc
# ?sort=Price+to+Earning&order=desc
# ?sort=Market+Capitalization&order=desc
# ?sort=Dividend+yield&order=desc
# ?sort=Net+Profit+latest+quarter&order=desc
# ?sort=YOY+Quarterly+profit+growth&order=desc
# ?sort=Sales+latest+quarter&order=desc
# ?sort=YOY+Quarterly+sales+growth&order=desc
# ?sort=Return+on+capital+employed&order=desc
# ?sort=Return+on+equity&order=desc
# /company/BOMDYEING/
# /company/521178/
# /company/REFEX/
# /company/IOLCP/
# /company/PGHH/
# /company/532485/
# /company/508486/
# /company/DOLAT/
# /company/PARACABLES/
# /company/CAPLIPOINT/consolidated/
# /company/505358/
# /company/VSTIND/
# /company/POKARNA/consolidated/
# /company/GUFICBIO/
# /company/524790/
# ?order=asc
# ?sort=name&order=desc
# ?sort=Current+Price&order=desc
# ?sort=Price+to+Earning&order=desc
# ?sort=Market+Capitalization&order=desc
# ?sort=Dividend+yield&order=desc
# ?sort=Net+Profit+latest+quarter&order=desc
# ?sort=YOY+Quarterly+profit+growth&order=desc
# ?sort=Sales+latest+quarter&order=desc
# ?sort=YOY+Quarterly+sales+growth&order=desc
# ?sort=Return+on+capital+employed&order=desc
# ?sort=Return+on+equity&order=desc
# /company/SATIA/
# /company/514183/
# /company/530741/
# /company/BHARATRAS/
# /company/HINDOILEXP/
# /company/LTTS/
# /company/ARMANFIN/consolidated/
# /company/500319/
# /company/WSTCSTPAPR/
# /company/DFMFOODS/
